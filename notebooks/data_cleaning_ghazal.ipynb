# %%
import pandas as pd
import numpy as np
df = pd.read_csv("../data/raw/merged_table_alexandra.csv")
df
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#          order_approved_at order_delivered_timestamp  \
# ...

# %%
#product_category_name column
df['product_category_name'].nunique()
# Out:
# 70

# %%
df['product_category_name'].isnull().sum()
# Out:
# np.int64(308)

# %%
#product_category_name column
#Convert to lowercase
df['product_category_name'] = df['product_category_name'].str.lower()
df['product_category_name']
# Out:
# 0                            toys
# 1                   watches_gifts
# 2        costruction_tools_garden
# 3                            toys
# 4                            toys
#                    ...
# 89311                        toys
# 89312                        toys
# 89313               health_beauty
# 89314                        toys
# 89315                        toys
# Name: product_category_name, Length: 89316, dtype: object

# %%
#filling missing values with unknown
df["product_category_name"] = df["product_category_name"].fillna("unknown")
df["product_category_name"]
# Out:
# 0                            toys
# 1                   watches_gifts
# 2        costruction_tools_garden
# 3                            toys
# 4                            toys
#                    ...
# 89311                        toys
# 89312                        toys
# 89313               health_beauty
# 89314                        toys
# 89315                        toys
# Name: product_category_name, Length: 89316, dtype: object

# %%
df['product_category_name'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['product_category_name'].unique()
# Out:
# array(['toys', 'watches_gifts', 'costruction_tools_garden',
#        'bed_bath_table', 'auto', 'health_beauty', 'cool_stuff',
#        'garden_tools', 'furniture_decor', 'fashion_shoes',
#        'sports_leisure', 'baby', 'housewares',
#        'construction_tools_construction', 'electronics',
#        'home_appliances', 'audio', 'consoles_games', 'stationery',
#        'furniture_living_room', 'computers_accessories', 'perfumery',
#        'kitchen_dining_laundry_garden_furniture',
#        'fashion_bags_accessories', 'market_place', 'telephony',
#        'home_construction', 'unknown', 'office_furniture',
#        'industry_commerce_and_business', 'food_drink', 'drinks',
#        'agro_industry_and_commerce', 'signaling_and_security', 'food',
#        'pet_shop', 'luggage_accessories', 'home_appliances_2',
#        'small_appliances', 'tablets_printing_image',
#        'construction_tools_lights', 'musical_instruments', 'home_confort',
# ...

# %%
df['product_category_name'] = df['product_category_name'].str.strip()
df['product_category_name'] = df['product_category_name'].str.replace(r'\s+', ' ', regex=True)

# %%
sorted(df['product_category_name'].unique())
# Out:
# ['agro_industry_and_commerce',
#  'air_conditioning',
#  'art',
#  'arts_and_craftmanship',
#  'audio',
#  'auto',
#  'baby',
#  'bed_bath_table',
#  'books_general_interest',
#  'books_imported',
#  'books_technical',
#  'christmas_supplies',
#  'cine_photo',
#  'computers',
#  'computers_accessories',
#  'consoles_games',
#  'construction_tools_construction',
#  'construction_tools_lights',
#  'construction_tools_safety',
#  'cool_stuff',
#  'costruction_tools_garden',
#  'costruction_tools_tools',
#  'diapers_and_hygiene',
#  'drinks',
#  'dvds_blu_ray',
#  'electronics',
#  'fashio_female_clothing',
#  'fashion_bags_accessories',
#  'fashion_childrens_clothes',
#  'fashion_male_clothing',
#  'fashion_shoes',
#  'fashion_sport',
#  'fashion_underwear_beach',
#  'fixed_telephony',
#  'flowers',
#  'food',
#  'food_drink',
#  'furniture_bedroom',
#  'furniture_decor',
#  'furniture_living_room',
#  'furniture_mattress_and_upholstery',
#  'garden_tools',
#  'health_beauty',
# ...

# %%
#missspelling
fixes = {
    'costruction_tools_garden': 'construction_tools_garden',
    'costruction_tools_tools': 'construction_tools_tools',
    'fashio_female_clothing': 'fashion_female_clothing',

    'home_confort': 'home_comfort',
    'home_comfort_2': 'home_comfort',

    'home_appliances_2': 'home_appliances',
    'small_appliances': 'home_appliances',
    'small_appliances_home_oven_and_coffee': 'home_appliances',

    'food_drink': 'food_and_drinks',
    'drinks': 'food_and_drinks',
    'food': 'food_and_drinks'
}

df['product_category_name'] = df['product_category_name'].replace(fixes)

# %%
df['product_category_name'].nunique()
# Out:
# 65

# %%
df['product_category_name'].value_counts().head(10)
# Out:
# product_category_name
# toys                     67027
# health_beauty             2351
# bed_bath_table            2146
# sports_leisure            1837
# furniture_decor           1760
# computers_accessories     1715
# housewares                1340
# watches_gifts             1196
# telephony                  912
# auto                       829
# Name: count, dtype: int64

# %%
df['product_category_name'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['product_category_name'].value_counts().loc['unknown']
# Out:
# np.int64(308)

# %%
#product_weight_g
df['product_weight_g'].isnull().sum()
# Out:
# np.int64(15)

# %%
df['product_weight_g'].describe()
# Out:
# count    89301.000000
# mean      2087.068129
# std       3747.039215
# min          0.000000
# 25%        300.000000
# 50%        700.000000
# 75%       1800.000000
# max      40425.000000
# Name: product_weight_g, dtype: float64

# %%
#how many 0 s exist?
(df['product_weight_g'] == 0).sum()
# Out:
# np.int64(6)

# %%
df['product_weight_g'] = df['product_weight_g'].replace(0, np.nan)

# %%
df= df['product_weight_g'].dropna

# %%
#check for negative values
(df['product_weight_g'] < 0).sum()
# Out:
# np.int64(0)

# %%
# product_length_cm
df['product_length_cm'].isnull().sum()
# Out:
# np.int64(15)

# %%
df['product_length_cm'].describe()
# Out:
# count    89301.000000
# mean        30.220658
# std         16.110199
# min          7.000000
# 25%         18.000000
# 50%         25.000000
# 75%         38.000000
# max        105.000000
# Name: product_length_cm, dtype: float64

# %%
(df['product_length_cm'] == 0).sum()
# Out:
# np.int64(0)

# %%
(df['product_length_cm'] < 0).sum()
# Out:
# np.int64(0)

# %%
df= df['product_length_cm'].dropna

# %%
#product height
df['product_height_cm'].isnull().sum()
# Out:
# np.int64(15)

# %%
df['product_height_cm'].describe()
# Out:
# count    89301.000000
# mean        16.559423
# std         13.388514
# min          2.000000
# 25%          8.000000
# 50%         13.000000
# 75%         20.000000
# max        105.000000
# Name: product_height_cm, dtype: float64

# %%
(df['product_height_cm'] == 0).sum()
# Out:
# np.int64(0)

# %%
(df['product_height_cm'] < 0).sum()
# Out:
# np.int64(0)

# %%
df= df['product_height_cm'].dropna

# %%
#product width
df['product_width_cm'].isnull().sum()
# Out:
# np.int64(15)

# %%
df['product_width_cm'].describe()
# Out:
# count    89301.00000
# mean        23.03421
# std         11.68828
# min          6.00000
# 25%         15.00000
# 50%         20.00000
# 75%         30.00000
# max        118.00000
# Name: product_width_cm, dtype: float64

# %%
(df['product_width_cm'] == 0).sum()
# Out:
# np.int64(0)

# %%
(df['product_width_cm'] < 0).sum()
# Out:
# np.int64(0)

# %%
df= df['product_width_cm'].dropna

# %%
#checking
df[['product_weight_g',
    'product_length_cm',
    'product_height_cm',
    'product_width_cm']].describe()
# Out:
#        product_weight_g  product_length_cm  product_height_cm  \
# count      89301.000000       89301.000000       89301.000000
# mean        2087.068129          30.220658          16.559423
# std         3747.039215          16.110199          13.388514
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1800.000000          38.000000          20.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count       89301.00000
# mean           23.03421
# std            11.68828
# min             6.00000
# 25%            15.00000
# 50%            20.00000
# 75%            30.00000
# max           118.00000

# %%
df[['product_weight_g',
    'product_length_cm',
    'product_height_cm',
    'product_width_cm']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_weight_g   89301 non-null  float64
#  1   product_length_cm  89301 non-null  float64
#  2   product_height_cm  89301 non-null  float64
#  3   product_width_cm   89301 non-null  float64
# dtypes: float64(4)
# memory usage: 2.7 MB

# %%
df[['product_weight_g',
    'product_length_cm',
    'product_height_cm',
    'product_width_cm']].head()
# Out:
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             491.0               19.0               12.0              16.0
# 1             440.0               18.0               14.0              17.0
# 2            2200.0               16.0               16.0              16.0
# 3            1450.0               68.0                3.0              48.0
# 4             300.0               17.0                4.0              12.0

# %%
cleaned_cols = [
    'product_category_name',
    'product_weight_g',
    'product_length_cm',
    'product_height_cm',
    'product_width_cm'
]

df_cleaned = df[cleaned_cols]

# %%
df_cleaned.to_csv("cleaned_products_columns_ghazal.csv", index=False)
